# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv('CKD.csv')

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
dataset['classification_yes'].value_counts()
# Out:
# classification_yes
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

# %%
dep=dataset[['classification_yes']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'C':[1],'kernel':['linear', 'poly', 'rbf', 'sigmoid'],'gamma':['scale', 'auto']}

# %%
grid=GridSearchCV(SVC(),param_grid,refit=True,verbose=3,n_jobs=1,scoring='f1_weighted')

# %%
grid=grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END ...C=1, gamma=scale, kernel=linear;, score=0.982 total time=   0.0s
# [CV 2/5] END ...C=1, gamma=scale, kernel=linear;, score=0.962 total time=   0.0s
# [CV 3/5] END ...C=1, gamma=scale, kernel=linear;, score=0.981 total time=   0.0s
# [CV 4/5] END ...C=1, gamma=scale, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END ...C=1, gamma=scale, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=scale, kernel=poly;, score=1.000 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=scale, kernel=poly;, score=0.962 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=scale, kernel=poly;, score=0.981 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=scale, kernel=poly;, score=0.962 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=scale, kernel=poly;, score=0.981 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.982 total time=   0.0s
# ...

# %%
re=grid.cv_results_

# %%
print('best params{}:'.format(grid.best_params_))
# Out:
# best params{'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}:

# %%
grid_predictions=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_predictions)

# %%
cm
# Out:
# array([[51,  0],
#        [ 1, 81]], dtype=int64)

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_predictions)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        51
#            1       1.00      0.99      0.99        82
#
#     accuracy                           0.99       133
#    macro avg       0.99      0.99      0.99       133
# weighted avg       0.99      0.99      0.99       133

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid_predictions)
# Out:
# 0.9939024390243902

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.003263      0.003040         0.005567        0.001131       1
# 1       0.003217      0.003681         0.003270        0.002351       1
# 2       0.002660      0.001786         0.005981        0.001186       1
# 3       0.001781      0.001390         0.004575        0.001377       1
# 4       0.002092      0.001824         0.003587        0.003867       1
# 5       0.002423      0.001727         0.005373        0.002050       1
# 6       0.003595      0.002105         0.007359        0.002844       1
# 7       0.001184      0.001874         0.005002        0.002480       1
#
#   param_gamma param_kernel                                           params  \
# 0       scale       linear   {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 1       scale         poly     {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 2       scale          rbf      {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# ...

# %%
grid.predict([[26,76,3,0,148,57,3,137,4.62,12.51,0,0,0,0,0,0,1,1,0,1,1,1,0,0,0,1,0]])
# Out:
# array([1])

# %%
import pickle

# %%
filename=('final_model_svc.sav')

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("final_model_svc.sav","rb"))

# %%
result=loaded_model.predict([[26,76,3,0,148,57,3,137,4.62,12.51,0,0,0,0,0,0,1,1,0,1,1,1,0,0,0,1,0]])

# %%
result
# Out:
# array([1])
